# %% [markdown]
# ## LENDING CLUB CASE STUDY

# %%
# Importing all the required libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #####  *Importing dataset*

# %%
df=pd.read_csv(r"C:\Users\jayan\Downloads\loan\loan.csv",low_memory=False)

# %% [markdown]
# #####  *Needs to understand dataset*

# %%
df.shape
# Out:
# (39717, 111)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %%
df.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
#        'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens',
#        'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit'],
#       dtype='object', length=111)

# %% [markdown]
# #####  *Checking for Null Values*

# %%
df.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
#                               ...
# tax_liens                        39
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 111, dtype: int64

# %% [markdown]
# ###### *after checking this will get to know there are colunms that are</br> having all nulll vlaues so will remove those colunms first*

# %%
df_cleaned=df.dropna(axis=1,how="all")    # dropping colunms with all Nan Values

# %%
df_cleaned.shape   # will see colunms are reduced
# Out:
# (39717, 57)

# %% [markdown]
# ##### *Handling Missing Values*

# %%
df_cleaned.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
# term                              0
# int_rate                          0
# installment                       0
# grade                             0
# sub_grade                         0
# emp_title                      2459
# emp_length                     1075
# home_ownership                    0
# annual_inc                        0
# verification_status               0
# issue_d                           0
# loan_status                       0
# pymnt_plan                        0
# url                               0
# desc                          12940
# purpose                           0
# title                            11
# zip_code                          0
# addr_state                        0
# dti                               0
# delinq_2yrs                       0
# ...

# %%
# we are seeing some colunms are having more than 50% values are missing so we rmove those too
col=['mths_since_last_delinq','next_pymnt_d','mths_since_last_record']
df_cleaned.drop(columns=col,inplace=True)
# Out:
# C:\Users\jayan\AppData\Local\Temp\ipykernel_22040\1479512706.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned.drop(columns=col,inplace=True)

# %%
df_cleaned.shape
# Out:
# (39717, 54)

# %%
df_cleaned.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
# term                              0
# int_rate                          0
# installment                       0
# grade                             0
# sub_grade                         0
# emp_title                      2459
# emp_length                     1075
# home_ownership                    0
# annual_inc                        0
# verification_status               0
# issue_d                           0
# loan_status                       0
# pymnt_plan                        0
# url                               0
# desc                          12940
# purpose                           0
# title                            11
# zip_code                          0
# addr_state                        0
# dti                               0
# delinq_2yrs                       0
# ...

# %%
# will drop the rows for desc missed values
df_cleaned=df_cleaned[df_cleaned["desc"].isnull()==False]

# %%
df_cleaned.shape
# Out:
# (26777, 54)

# %%
df_cleaned.isnull().sum()
# Out:
# id                               0
# member_id                        0
# loan_amnt                        0
# funded_amnt                      0
# funded_amnt_inv                  0
# term                             0
# int_rate                         0
# installment                      0
# grade                            0
# sub_grade                        0
# emp_title                     1604
# emp_length                     630
# home_ownership                   0
# annual_inc                       0
# verification_status              0
# issue_d                          0
# loan_status                      0
# pymnt_plan                       0
# url                              0
# desc                             0
# purpose                          0
# title                            6
# zip_code                         0
# addr_state                       0
# dti                              0
# delinq_2yrs                      0
# earliest_cr_line                 0
# ...

# %%
# Similarly will do for emp_title
df_cleaned=df_cleaned[df_cleaned["emp_title"].isnull()==False]

# %%
df_cleaned.shape
# Out:
# (25173, 54)

# %%
df_cleaned.isnull().sum()
# Out:
# id                              0
# member_id                       0
# loan_amnt                       0
# funded_amnt                     0
# funded_amnt_inv                 0
# term                            0
# int_rate                        0
# installment                     0
# grade                           0
# sub_grade                       0
# emp_title                       0
# emp_length                     38
# home_ownership                  0
# annual_inc                      0
# verification_status             0
# issue_d                         0
# loan_status                     0
# pymnt_plan                      0
# url                             0
# desc                            0
# purpose                         0
# title                           5
# zip_code                        0
# addr_state                      0
# dti                             0
# delinq_2yrs                     0
# earliest_cr_line                0
# ...

# %%
# Similarly will do for pub_rec_bankruptcies
df_cleaned=df_cleaned[df_cleaned["pub_rec_bankruptcies"].isnull()==False]

# %%
df_cleaned.isnull().sum()
# Out:
# id                             0
# member_id                      0
# loan_amnt                      0
# funded_amnt                    0
# funded_amnt_inv                0
# term                           0
# int_rate                       0
# installment                    0
# grade                          0
# sub_grade                      0
# emp_title                      0
# emp_length                    38
# home_ownership                 0
# annual_inc                     0
# verification_status            0
# issue_d                        0
# loan_status                    0
# pymnt_plan                     0
# url                            0
# desc                           0
# purpose                        0
# title                          5
# zip_code                       0
# addr_state                     0
# dti                            0
# delinq_2yrs                    0
# earliest_cr_line               0
# inq_last_6mths                 0
# ...

# %%
df_cleaned=df_cleaned[df_cleaned['emp_length'].isnull()==False]

# %%
df_cleaned=df_cleaned[df_cleaned['revol_util'].isnull()==False]
df_cleaned=df_cleaned[df_cleaned['last_pymnt_d'].isnull()==False]

# %%
df_cleaned.isnull().sum()
# Out:
# id                            0
# member_id                     0
# loan_amnt                     0
# funded_amnt                   0
# funded_amnt_inv               0
# term                          0
# int_rate                      0
# installment                   0
# grade                         0
# sub_grade                     0
# emp_title                     0
# emp_length                    0
# home_ownership                0
# annual_inc                    0
# verification_status           0
# issue_d                       0
# loan_status                   0
# pymnt_plan                    0
# url                           0
# desc                          0
# purpose                       0
# title                         5
# zip_code                      0
# addr_state                    0
# dti                           0
# delinq_2yrs                   0
# earliest_cr_line              0
# inq_last_6mths                0
# open_acc                      0
# ...

# %%
df["chargeoff_within_12_mths"].mode()[0]
# Out:
# 0.0

# %%
# Will Impute the values for the left out colunms

df_cleaned["title"].fillna(df_cleaned["title"].mode()[0],inplace=True)

# %%
df_cleaned.isnull().sum()
# Out:
# id                            0
# member_id                     0
# loan_amnt                     0
# funded_amnt                   0
# funded_amnt_inv               0
# term                          0
# int_rate                      0
# installment                   0
# grade                         0
# sub_grade                     0
# emp_title                     0
# emp_length                    0
# home_ownership                0
# annual_inc                    0
# verification_status           0
# issue_d                       0
# loan_status                   0
# pymnt_plan                    0
# url                           0
# desc                          0
# purpose                       0
# title                         0
# zip_code                      0
# addr_state                    0
# dti                           0
# delinq_2yrs                   0
# earliest_cr_line              0
# inq_last_6mths                0
# open_acc                      0
# ...

# %%
# Will do same for leftouts

df_cleaned["chargeoff_within_12_mths"].fillna(df_cleaned["chargeoff_within_12_mths"].mode()[0],inplace=True)

df_cleaned["collections_12_mths_ex_med"].fillna(df_cleaned["collections_12_mths_ex_med"].mode()[0],inplace=True)

# %%
df_cleaned.isnull().sum()
# Out:
# id                            0
# member_id                     0
# loan_amnt                     0
# funded_amnt                   0
# funded_amnt_inv               0
# term                          0
# int_rate                      0
# installment                   0
# grade                         0
# sub_grade                     0
# emp_title                     0
# emp_length                    0
# home_ownership                0
# annual_inc                    0
# verification_status           0
# issue_d                       0
# loan_status                   0
# pymnt_plan                    0
# url                           0
# desc                          0
# purpose                       0
# title                         0
# zip_code                      0
# addr_state                    0
# dti                           0
# delinq_2yrs                   0
# earliest_cr_line              0
# inq_last_6mths                0
# open_acc                      0
# ...

# %% [markdown]
# ##### *Now we have dataset having all non null values now wee need to look for correct datatypes to colunms*

# %%
df_cleaned.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
# 6  1069639    1304742       7000         7000           7000.0   60 months
# 7  1072053    1288686       3000         3000           3000.0   36 months
#
#   int_rate  installment grade sub_grade  ... last_pymnt_amnt  \
# 1   15.27%        59.83     C        C4  ...          119.66
# 3   13.49%       339.31     C        C1  ...          357.48
# 4   12.69%        67.79     B        B5  ...           67.79
# 6   15.96%       170.08     C        C5  ...         1313.76
# 7   18.64%       109.43     E        E1  ...          111.34
#
#   last_credit_pull_d collections_12_mths_ex_med  policy_code application_type  \
# ...

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24413 entries, 1 to 39680
# Data columns (total 54 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          24413 non-null  int64
#  1   member_id                   24413 non-null  int64
#  2   loan_amnt                   24413 non-null  int64
#  3   funded_amnt                 24413 non-null  int64
#  4   funded_amnt_inv             24413 non-null  float64
#  5   term                        24413 non-null  object
#  6   int_rate                    24413 non-null  object
#  7   installment                 24413 non-null  float64
#  8   grade                       24413 non-null  object
#  9   sub_grade                   24413 non-null  object
#  10  emp_title                   24413 non-null  object
#  11  emp_length                  24413 non-null  object
#  12  home_ownership              24413 non-null  object
# ...

# %%
# As intreast rate is having object data type will change it to float
df_cleaned.int_rate=df_cleaned["int_rate"].apply(lambda x: 0 if x=='0%' else float(x[:-1]))

# %%
df_cleaned.int_rate.describe()
# Out:
# count    24413.000000
# mean        12.091306
# std          3.651450
# min          5.420000
# 25%          9.620000
# 50%         11.890000
# 75%         14.460000
# max         24.400000
# Name: int_rate, dtype: float64

# %%
# As intreast rate is having object data type will change it to float
df_cleaned.revol_util=df_cleaned["revol_util"].apply(lambda x: 0 if x=='0%' else float(x[:-1]))
df_cleaned.revol_util.head()
# Out:
# 1     9.4
# 3    21.0
# 4    53.9
# 6    85.6
# 7    87.5
# Name: revol_util, dtype: float64

# %%
df_cleaned.revol_util.describe()
# Out:
# count    24413.000000
# mean        49.042583
# std         28.074611
# min          0.000000
# 25%         26.000000
# 50%         49.500000
# 75%         72.100000
# max         99.900000
# Name: revol_util, dtype: float64

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24413 entries, 1 to 39680
# Data columns (total 54 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          24413 non-null  int64
#  1   member_id                   24413 non-null  int64
#  2   loan_amnt                   24413 non-null  int64
#  3   funded_amnt                 24413 non-null  int64
#  4   funded_amnt_inv             24413 non-null  float64
#  5   term                        24413 non-null  object
#  6   int_rate                    24413 non-null  float64
#  7   installment                 24413 non-null  float64
#  8   grade                       24413 non-null  object
#  9   sub_grade                   24413 non-null  object
#  10  emp_title                   24413 non-null  object
#  11  emp_length                  24413 non-null  object
#  12  home_ownership              24413 non-null  object
# ...

# %% [markdown]
# ##### *Now will do the sanity check*

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24413 entries, 1 to 39680
# Data columns (total 54 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          24413 non-null  int64
#  1   member_id                   24413 non-null  int64
#  2   loan_amnt                   24413 non-null  int64
#  3   funded_amnt                 24413 non-null  int64
#  4   funded_amnt_inv             24413 non-null  float64
#  5   term                        24413 non-null  object
#  6   int_rate                    24413 non-null  float64
#  7   installment                 24413 non-null  float64
#  8   grade                       24413 non-null  object
#  9   sub_grade                   24413 non-null  object
#  10  emp_title                   24413 non-null  object
#  11  emp_length                  24413 non-null  object
#  12  home_ownership              24413 non-null  object
# ...

# %%
df_cleaned["initial_list_status"].head()
# Out:
# 1    f
# 3    f
# 4    f
# 6    f
# 7    f
# Name: initial_list_status, dtype: object

# %%
# Since possible values in initial_list_status are W and F

df_cleaned[(df_cleaned["initial_list_status"]=='w') & (df_cleaned["initial_list_status"]!='f')].shape
# Out:
# (0, 54)

# %%
df_cleaned["home_ownership"].head()
# Out:
# 1    RENT
# 3    RENT
# 4    RENT
# 6    RENT
# 7    RENT
# Name: home_ownership, dtype: object

# %%
# Since possible values in home_ownership are: RENT, OWN, MORTGAGE, OTHER

df_cleaned[~df_cleaned["home_ownership"].isin(['RENT', 'OWN', 'MORTGAGE', 'OTHER'])].shape
# Out:
# (0, 54)

# %% [markdown]
# ###### *Note: FICO value is type of credit score value that lies in the range of 300 to 850 -</br> 1. 300 - 579: Poor </br>  2. 580 - 669: Fair </br> 3. 670 - 739: Good 4.</br> 740 - 799: Very Good </br> 5. 800 - 850: Exceptional  </br> These colunms are present in excel.

# %%
df_cleaned["earliest_cr_line"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 24413 entries, 1 to 39680
# Series name: earliest_cr_line
# Non-Null Count  Dtype
# --------------  -----
# 24413 non-null  object
# dtypes: object(1)
# memory usage: 381.5+ KB

# %%
df_cleaned["funded_amnt"].head()
# Out:
# 1     2500
# 3    10000
# 4     3000
# 6     7000
# 7     3000
# Name: funded_amnt, dtype: int64

# %%
df_cleaned["funded_amnt_inv"].head()
# Out:
# 1     2500.0
# 3    10000.0
# 4     3000.0
# 6     7000.0
# 7     3000.0
# Name: funded_amnt_inv, dtype: float64

# %%
df_cleaned["revol_bal"].head()
# Out:
# 1     1687
# 3     5598
# 4    27783
# 6    17726
# 7     8221
# Name: revol_bal, dtype: int64

# %%
# term is 36 and 60 months only so we need to check that too
df_cleaned[(df_cleaned["term"]==" 60 months") | (df_cleaned["term"]==" 36 months")].shape
# Out:
# (24413, 54)

# %%
df_cleaned.shape
# Out:
# (24413, 54)

# %% [markdown]
# ##### *Now will handle and managing the outliers for numeric colunms*

# %%
numeric_df = df_cleaned.select_dtypes(include=['number'])

# %%
numeric_df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'int_rate', 'installment', 'annual_inc', 'dti', 'delinq_2yrs',
#        'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_amnt', 'collections_12_mths_ex_med', 'policy_code',
#        'acc_now_delinq', 'chargeoff_within_12_mths', 'delinq_amnt',
#        'pub_rec_bankruptcies', 'tax_liens'],
#       dtype='object')

# %%
df_cleaned["annual_inc"].describe()
# Out:
# count    2.441300e+04
# mean     6.933507e+04
# std      5.760189e+04
# min      4.000000e+03
# 25%      4.200000e+04
# 50%      6.000000e+04
# 75%      8.300000e+04
# max      3.900000e+06
# Name: annual_inc, dtype: float64

# %%
# Will look for outliers in annual_inc that is annual income colunm by using box plot first
plt.figure(figsize=(10, 6))
plt.title("Annual Income")
plt.boxplot(df_cleaned["annual_inc"])
plt.ylabel("Annual Income")
plt.show()

# %%
pd.options.display.float_format="{:.2f}".format
df_cleaned["annual_inc"].describe()
# Out:
# count     24413.00
# mean      69335.07
# std       57601.89
# min        4000.00
# 25%       42000.00
# 50%       60000.00
# 75%       83000.00
# max     3900000.00
# Name: annual_inc, dtype: float64

# %%
# as we see the 75% of the values of annual income colunms in the data set is lying below 830000 thats why we re able to see 
# lots of outlier will check using IQR methods how many outliers are there
Q1=df_cleaned["annual_inc"].quantile(0.25)
Q3=df_cleaned["annual_inc"].quantile(0.75)
IQR=Q3-Q1
IQR
# Out:
# 41000.0

# %%
# Now we are having IQR will check the shape of outliers
upperLimit=Q3+(1.5*IQR)
lowerLimit=Q1-(1.5*IQR)
print(upperLimit,lowerLimit)
df_outlier=df_cleaned[(df_cleaned["annual_inc"]<lowerLimit) | (df_cleaned["annual_inc"]>upperLimit)]
# Out:
# 144500.0 -19500.0

# %%
df_outlier["annual_inc"].shape
# Out:
# (1117,)

# %% [markdown]
# ##### *Hence there are 1117 outliers in annual_income colunm will handle outliers either will remove it or replacing it with the nearest values fro the annual income I am removing outliers because they are having high chance of repaying*

# %%
df_cleaned=df_cleaned[(df_cleaned["annual_inc"]<=lowerLimit) | (df_cleaned["annual_inc"]<=upperLimit)]
df_cleaned.shape
# Out:
# (23296, 54)

# %% [markdown]
# ##### *Same will do for Loan amount colunm*

# %%
plt.title("Loan Amount")
df_cleaned["loan_amnt"].plot(kind="box")
# Out:
# <Axes: title={'center': 'Loan Amount'}>

# %%
df_cleaned["loan_amnt"].describe()
# Out:
# count   23296.00
# mean    11305.51
# std      7103.45
# min       500.00
# 25%      6000.00
# 50%     10000.00
# 75%     15000.00
# max     35000.00
# Name: loan_amnt, dtype: float64

# %%
Q1=df_cleaned["loan_amnt"].quantile(0.25)
Q3=df_cleaned["loan_amnt"].quantile(0.75)
IQR=Q3-Q1
IQR
# Out:
# 9000.0

# %%
ulLoanamnt= Q3+(1.5*IQR)
llLoanamnt=Q1-(1.5*IQR)
df_cleaned[(df_cleaned["loan_amnt"]<=llLoanamnt)|(df_cleaned["loan_amnt"]>=ulLoanamnt)].shape
# Out:
# (593, 54)

# %%
# This time will cap the values so that will not loose the data from the dataset

df_cleaned["loan_amnt"]=np.where(df_cleaned["loan_amnt"]>=ulLoanamnt,ulLoanamnt,np.where(df_cleaned["loan_amnt"]<=llLoanamnt,llLoanamnt,df_cleaned["loan_amnt"]))

# %%
df_cleaned["loan_amnt"].describe()
# Out:
# count   23296.00
# mean    11196.03
# std      6786.94
# min       500.00
# 25%      6000.00
# 50%     10000.00
# 75%     15000.00
# max     28500.00
# Name: loan_amnt, dtype: float64

# %% [markdown]
# ##### *Now as we see that we handles outliers from desired colunms and handled missing values as well now will start EDA*

# %% [markdown]
# #### Univariate and Segmented univariate analysis

# %%
# First will do univariate analysis for numerical 
# 1) Annual Income
plt.hist(df_cleaned['annual_inc'], bins=50)
plt.title('Annual Income Distribution')
plt.xlabel('Annual Income')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### *1. After seeing histogram for annual income we can say that most of the people is having salary between 40K and 60K per annum.*

# %%
# 2) Loan Amount
plt.hist(df_cleaned["loan_amnt"],bins=50)
plt.xlabel("Loan amount")
plt.ylabel("Frequency")
plt.title("Loan Amount Distribution")
# ticks=np.arange(0,30000,2000)
# label=["{}K".format(i//1000) for i in ticks]
# plt.xticks(ticks,label)
# Out:
# Text(0.5, 1.0, 'Loan Amount Distribution')

# %% [markdown]
# ##### *2. We can say that Company has given most loan amount between 5K and 15K and around 10K</br> most of the amount is disbused*

# %%
# We will see for categorical variable using Bar plot
# 1) Loan Status
df_cleaned["loan_status"].value_counts().plot(kind='bar')
plt.xlabel("Loan Status")
plt.ylabel("Count")
plt.title("Loan Status Label")
# Out:
# Text(0.5, 1.0, 'Loan Status Label')

# %% [markdown]
# ##### *3. Most of the Loan provided by the company is fully paid*

# %%
# 2) Home ownership
df_cleaned["home_ownership"].value_counts().plot(kind="bar")
plt.ylabel("Count")
plt.xlabel("Home ownership")
plt.title("Home ownership count")
# Out:
# Text(0.5, 1.0, 'Home ownership count')

# %% [markdown]
# ##### *4. Most of the borrower is either living in rented house or in Mortgage prvided during registration*

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=df_cleaned, x='loan_amnt', hue='loan_status', kde=True)
plt.title('Loan Amount Distribution Across Loan Status')
plt.xlabel('Loan Amount')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(x='purpose', y='int_rate', data=df_cleaned)
plt.title('Interest Rate Distribution Across Loan Purpose')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### *5. The median int_rate for vacation and for car is less whereas if purpose is small business then the intrest is high because that is considered to be high risk*

# %%
sns.barplot(x='loan_status', y='int_rate', data=df_cleaned)
plt.title('Interest Rate by Loan Status')
plt.xlabel('Loan Status')
plt.ylabel('Interest Rate')
plt.show()

# %%
df_cleaned["int_rate"].groupby(df_cleaned['loan_status']).describe()
# Out:
#                count  mean  std  min   25%   50%   75%   max
# loan_status
# Charged Off  3203.00 13.86 3.55 5.42 11.49 13.61 16.32 24.40
# Current       622.00 14.95 3.50 6.00 11.99 14.65 17.58 23.52
# Fully Paid  19471.00 11.65 3.51 5.42  8.88 11.49 13.98 24.11

# %% [markdown]
# ##### *6. By seeing above graphs and Table we can say that intreast rate in loans offered to lower risk borrower were less (fully paid) </br>whereas intreast rate on higher risk borrower (charged off) is more*

# %% [markdown]
# #### Bivariate analysis

# %%
loan_amnt_bin=pd.cut(df_cleaned["loan_amnt"],bins=5)
df_cleaned["annual_inc"].groupby(loan_amnt_bin).mean()
# Out:
# loan_amnt
# (472.0, 6100.0]      50478.04
# (6100.0, 11700.0]    58459.29
# (11700.0, 17300.0]   66540.67
# (17300.0, 22900.0]   73930.24
# (22900.0, 28500.0]   87893.20
# Name: annual_inc, dtype: float64

# %%
plt.xlabel('Loan Amount')
plt.ylabel('Annual income')
plt.title("Loan Amount and Anuual Income")
df_cleaned["annual_inc"].groupby(loan_amnt_bin).mean().plot(kind='bar')
# Out:
# <Axes: title={'center': 'Loan Amount and Anuual Income'}, xlabel='loan_amnt', ylabel='Annual income'>

# %% [markdown]
# ##### *1. By gruoping loan amount into bins we can say that more is the salary more is the loan amnt will clear it by using scatterplot*

# %%
plt.xlabel('Loan Amount')
plt.ylabel('Annual income')
plt.title("Loan Amount and Anuual Income")
sns.scatterplot(df_cleaned,x='loan_amnt',y='annual_inc' )
# Out:
# <Axes: title={'center': 'Loan Amount and Anuual Income'}, xlabel='Loan Amount', ylabel='Annual income'>

# %% [markdown]
# ##### *2. By scatterplot we can say that the loan amount that disbursed is similar to various salary range </br> chances of getting loan in low salary is minimal.*

# %%
ct=pd.crosstab(df_cleaned['grade'],df_cleaned['loan_status'])

# %%
sns.heatmap(ct,annot=True,fmt='d',cmap='YlGnBu')
plt.title("Grade vs Loan Status")
# Out:
# Text(0.5, 1.0, 'Grade vs Loan Status')

# %% [markdown]
# ##### *2.1  Higher grades (A and B) not only have more loans but also have a significantly larger number of fully paid loans.</br> This suggests that borrowers with higher grades are more likely to fully repay their loans.*

# %% [markdown]
# ##### *2.2  As we see in charged off most of the loans are in above grade then there is a high chances of repayment.*

# %%
ct=pd.crosstab(df_cleaned["loan_status"],df_cleaned["home_ownership"])

# %%
sns.heatmap(ct,annot=True,fmt='d',cmap='YlGnBu')
plt.show()

# %% [markdown]
# ##### *3. Most of the loans that are present in charged off is having home owner ship as either rent or on mortgae </br> this is the negative sign for organization in terms for recovery*

# %%
df_cleaned["delinq_2yrs"].groupby(df_cleaned['loan_status']).mean().plot()
# Out:
# <Axes: xlabel='loan_status'>

# %% [markdown]
# ##### *4. The loans that are in charged off is having more no. "30+ days past-due" loans as compare to other </br> which means lending to fully paid and current borrowers would be recommended to organization*

# %%
plt.figure(figsize=(12, 6))
emporder= [
    '< 1 year', '1 year', '2 years', '3 years', '4 years',
    '5 years', '6 years', '7 years', '8 years', '9 years', '10+ years']
sns.boxplot(x='emp_length', y='loan_amnt', hue='loan_status', data=df_cleaned)
plt.title('Loan Amount Distribution by Employment Length and Loan Status')
plt.show()

# %% [markdown]
# ##### *5. Borrowers with longer employment lengths, particularly those with 10+ years of employment, tend to receive higher loan amounts. The median loan amount for these groups is consistently higher compared to those with shorter employment lengths.<\br>also that borrowers with shorter employment lengths (less than 1 year) have a higher proportion of Charged Off loans compared to those with longer employment lengths. This suggests that shorter employment lengths may be associated with higher default risk.*

# %% [markdown]
# #### Derived Metric

# %% [markdown]
# ##### *First will add monthly salary field in dataset helps for creating MI(monthly-installment) ratio*

# %%
df_cleaned["monthly_salary"]=df_cleaned["annual_inc"]/12

# %%
# Will see the monthly salary colunm
df_cleaned["monthly_salary"].describe()
# Out:
# count   23296.00
# mean     5174.59
# std      2302.62
# min       333.33
# 25%      3416.67
# 50%      4833.33
# 75%      6583.33
# max     12041.67
# Name: monthly_salary, dtype: float64

# %%
installment_bin=pd.cut(df_cleaned["installment"],bins=6)
plt.ylabel("Monthly Salary")
df_cleaned["monthly_salary"].groupby(installment_bin).mean().plot(kind="bar")
plt.show()

# %% [markdown]
# ##### *4. People having more monthly salary having more installment. This new monthly salary colunm will help lenders to provide new loans to borrowers*

# %%
filtered_df = df_cleaned[df_cleaned["home_ownership"] == 'RENT']
print(filtered_df.monthly_salary.mean(),"\n",filtered_df.installment.mean())

# Borrower lives in rental home having higher mean salary as compare to installments so that might gives the 
# good sign to lenders to provide the loan.
# Out:
# 4529.031683885499
#  303.7692981691369
